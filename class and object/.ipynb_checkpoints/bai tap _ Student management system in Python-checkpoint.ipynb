# %%
class sinhvien:
    def __init__(self,ma,ten,tuoi,nganh,lop):
        self.ma = ma
        self.ten = ten
        self.tuoi = tuoi
        self.nganh = nganh
        self.lop = lop
class danhsachsv:
    def __init__(self):
        self.danh_sach = []
    def them(self):
        print("*** chức năng thêm sinh viên ***")
        ma = input("nhập mã sv: ")
        ten = input("nhập tên sinh viên: ")
        tuoi = input("nhập tuổi sinh viên: ")
        nganh = input("nhập ngành học của sinh viên: ")
        lop = input("nhập lớp: ")
        sinh_vien = sinhvien(ma,ten,tuoi,nganh,lop)
        self.danh_sach.append(sinh_vien) 
    def hien_thi(seft):
        print("*** chức năng hiển thị danh sách *** ")
        
        
        
class mainapp:
    def chay(self):
        danh_sach_sv = danhsachsv()
        while True:
            print("=== chương trình quản lý sinh viên ===")
            print("1. xem danh sách sinh viên")
            print("2. thêm sinh viên mới vào danh sách")
            print("3. cập nhật thông  tin sinh viên")
            print("4. xóa sinh viên khỏi danh sách")
            print("5. tìm kiếm thông tin sinh viên")
            print("6. sắp xếp thông tin sinh viên trong danh sách")
            print("7. thoát")
            lua_chon = input("chọn các chức năng như trên: ")
            if lua_chon == '1':
                danhsachsv.hien_thi()
            elif lua_chon == '2':
                danhsachsv.them()
            elif lua_chon == '3':
                pass
            elif lua_chon == '4':
                pass
            elif lua_chon == '5':
                pass
            elif lua_chon == '6':
                pass
            elif lua_chon == '7':
                return
chuong_trinh_chinh = mainapp()
chuong_trinh_chinh.chay()
# Out:
# === chương trình quản lý sinh viên ===
# 1. xem danh sách sinh viên
# 2. thêm sinh viên mới vào danh sách
# 3. cập nhật thông  tin sinh viên
# 4. xóa sinh viên khỏi danh sách
# 5. tìm kiếm thông tin sinh viên
# 6. sắp xếp thông tin sinh viên trong danh sách
# 7. thoát
# chọn các chức năng như trên: 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 52>()
#      50                 return
#      51 chuong_trinh_chinh = mainapp()
# ---> 52 chuong_trinh_chinh.chay()
#
# Input In [7], in mainapp.chay(self)
#      36 lua_chon = input("chọn các chức năng như trên: ")
#      37 if lua_chon == '1':
# ---> 38     danhsachsv.hien_thi()
#      39 elif lua_chon == '2':
#      40     danhsachsv.them()
#
# TypeError: hien_thi() missing 1 required positional argument: 'seft'

# %%
class student:
    def __init__(bg, ID, name, age=None, sex=None, address=None):
        bg.id=ID
        bg.name=name
        bg.age=age
        bg.sex=sex
        bg.address=address
    def show(bg):
        print("MSV:",bg.id)
        print("Tên:",bg.name)
        print("Tuổi:",bg.age)
        print("Giới tính:",bg.sex)
        print("Địa chỉ:",bg.address)

class stu_class:
    def __init__(self,lis):
        self.lis=lis
    def add(self, stu):
        self.stu=stu
        self.lis.append(self.stu)
    def find_name(self,find_name):
        result=[]
        for i in self.lis:
            if find_name in i.name:
                result.append(i)
        if result == []:
            print("Không tìm thấy crush của bạn!")
        else:
            print("Những người có thể bạn muốn tìm:")
            for j in result:
                j.show()
#     def filters(self):
    def show(self):
        print("Thông tin danh sách:")
        print("Sĩ số: ",len(self.lis))
        while True:    
            print("Bạn cần thêm thông tin nào khác?")
            print("1:Toàn bộ thông tin sinh viên")
            print("2:Danh sách tên sinh")
            print("Q:Trở lại Menu trước")            
            x=input()
            if x=='1':
                for i in self.lis:
                    i.show()
            elif x=='2':
                for i in self.lis:
                    print("Tên: {ten}  MSV: {ID}". format(ten=i.name, ID=i.id))
            elif x=='Q'or x=='q':
                break
            else:
                print("Mời bạn nhập lại!")
    def __del__(self,stu):
        bad_stu=self.lis.remove(stu)
        del bad_stu
    def find(self):
        pass
    def sort(self, choise):
        if choise=='1':
            self.lis.sort(key=filter_name)
        if choise=='2':
            self.lis.sort(key=filter_id)
        if choise=='3':
            self.lis.sort(key=filter_sex)
    def filter_name(a):
        b=a.name.split()[-1]
        return b
    def filter_id(a)
        return a.id
     def filter_sex(a)
        return a.sex   
Student_List=[]
def app():
    print("Cảm ơn bạn đã sử dụng phần mềm quản lý sinh viên của chúng tôi!")
    qlsv=stu_class(Student_List)
    while True:
        print("Bạn muốn làm gì?")  
        print("1:Xem danh mục sinh viên  4:Xóa thông tin")  
        print("2:Thêm sinh viên mới      5:Tìm kiếm thông tin") 
        print("3:Cập nhật thông tin      6:Sắp xếp thông tin")
        print("Q:Thoát chương trình")        
        bh=input()
        if bh=='1':
            qlsv.show()   
        elif bh=='2':
            while True:
                ID=input("Nhập mã sinh viên: ")
                name=input("Nhap ten: ")
                age=input("Nhap tuoi: ")
                sex=input("Nhap gioi tinh: ")
                address=input("Nhap dia chi: ")
                stu=student(ID,name, age, sex, address)
                print("Sinh viên vừa nhập:")
                stu.show()
                check=input("Nhap 'Y' de add, nhap 'N' de nhap lai")
                if check=='Y' or check=='y':
                    break
            qlsv.add(stu)                
        elif bh=='3':
            fn=input("Nhập tên cần tìm: ")
            qlsv.find_name(fn)
        elif bh=='4':
            qlsv.__del__()
        elif bh=='5':
            qlsv.find()
        elif bh=='6':
            while True:
                choise=input('1:Theo tên 2:Theo mã sinh viên 3:Theo giới tính')
                n=('1', '2', '3')
                if choise in n:
                    qlsv.sort(choise)
                    break
                else:
                    print("Mời bạn nhập lại!")
        elif bh=='q' or bh=='Q':
            print("Tạm biệt!")
            break
        else:
            print("Mời bạn nhập lại!")
app()

# %%
1
