# %%
import turtle
t=turtle.Turtle()
# ve hinh vuong so 1
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
# ve hinh vuong thu 2
t.penup()
t.backward(50)
t.right(72)
t.pendown()
t.forward(50)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(50)
# ve hinh vuong thu 3
t.right(72)
t.pendown()
t.forward(50)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(50)
# ve hinh vuong thu 4
t.right(72)
t.pendown()
t.forward(50)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(50)
# ve hinh vuong thu 5
t.right(72)
t.pendown()
t.forward(50)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(50)
turtle.done()
