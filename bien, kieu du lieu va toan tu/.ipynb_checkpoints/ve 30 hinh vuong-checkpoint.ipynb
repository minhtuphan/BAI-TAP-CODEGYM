# %%
import turtle
t=turtle.Turtle()
canh = 10
goc = 360/30
# vẽ hình vuông 1
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 2
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 2
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 3
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 3
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 4
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 4
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 5
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 5
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 6
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 6
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 7
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 7
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 8
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 8
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 9
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 9
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 10
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 10
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 11
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 11
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 12
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 12
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 13
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 13
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 14
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 14
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 15
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 15
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 16
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 16
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 17
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 17
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 18
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 18
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 19
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 19
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 20
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 20
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 21
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 21
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 22
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 22
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 23
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 23
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 24
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 24
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 25
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 25
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 26
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 26
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 27
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 27
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 28
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 28
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 29
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 29
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
# đến vị trí vẽ hình vuông 30
t.left(90)
t.forward(5)
t.right(goc)
canh = canh + 5
# vẽ hình vuông 30
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
turtle.done()
