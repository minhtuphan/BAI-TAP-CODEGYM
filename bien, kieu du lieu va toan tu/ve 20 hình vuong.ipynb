# %%
import turtle
t = turtle.Turtle()

canh = 100
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)
# hinh vuong
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
t.forward(canh)
t.left(90)
# goc giua cac hinh
t.left(360/20)

turtle.done()
