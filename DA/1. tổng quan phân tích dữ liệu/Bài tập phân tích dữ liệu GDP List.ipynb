# %%
import pandas as pd
import numpy as np
data = pd.read_csv('D:\DA - TÚ\Data\database\GDPlist.csv',
                  header=0, encoding = 'ISO-8859-1')
data.head()
# Out:
#         Country      Continent  GDP (millions of US$)
# 0   Afghanistan           Asia                  18181
# 1       Albania         Europe                  12847
# 2       Algeria         Africa                 190709
# 3        Angola         Africa                 100948
# 4     Argentina  South America                 447644

# %%
print (data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                125 non-null    object
#  1   Continent              125 non-null    object
#  2   GDP (millions of US$)  125 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 3.1+ KB
# None

# %%
# Bộ dữ liệu chứa bao nhiêu dòng, bao nhiêu cột
print(f'số hàng là {data.shape[0]} số cột là {data.shape[1]}')
# Out:
# số hàng là 125 số cột là 3

# %%
# Vẽ biểu đồ GDP của các quốc gia
import pandas as pd
import numpy as np
data = pd.read_csv('D:\DA - TÚ\Data\database\GDPlist.csv',
                  header=0, encoding = 'ISO-8859-1')
import matplotlib.pyplot as plt
# plt.hist(data['Country'], bins = 10000)
# plt.title("GDP của các quốc gia")
# plt.xlabel("Quốc Gia")
# plt.ylabel("GDP")
plt.figure(figsize=(50, 50))
x = data['Country']
y = data['GDP (millions of US$)']
plt.bar(x,y)
plt.show()

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('D:\DA - TÚ\Data\database\GDPlist.csv',
                  header=0, encoding = 'ISO-8859-1')
country_in_continet = data.groupby(['Continent'])['Country'].count().sort_values(ascending= False)
country_in_continet.head(15)
# Out:
# Continent
# Europe           37
# Asia             36
# Africa           29
# North America    11
# South America     9
# Oceania           3
# Name: Country, dtype: int64

# %%
GDP_continet = data.groupby(['Country'])['GDP (millions of US$)'].sum().sort_values(ascending= False)
GDP_continet.head(15)
# Out:
# Country
#  United States     15094025
#  China              7298147
#  Japan              5869471
#  Germany            3577031
#  France             2776324
#  Brazil             2492908
#  United Kingdom     2417570
#  Italy              2198730
#  Russia             1850401
#  Canada             1736869
#  India              1676143
#  Spain              1493513
#  Australia          1488221
#  Mexico             1154784
#  South Korea        1116247
# Name: GDP (millions of US$), dtype: int64
