# %%
# Đọc dữ liệu từ file csv
import pandas as pd
import numpy as np
data = pd.read_csv('FoodPrice_in_Turkey.csv',
                  header=0, encoding = 'ISO-8859-1')
data
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# ...

# %%
# Đọc dữ liệu từ file excel
import pandas as pd
import numpy as np
data2 = pd.read_excel('D:\DA - TÚ\Data\database\house_price_Dống-Da.xlsx',
                   header=0, encoding = 'ISO-8859-1')
data2

# %%
# Đọc dữ liệu từ file Json
df = pd.read_json('FoodPrice.json')
df.head()

# %%
# Đọc dữ liệu từ file hdf5
df=pd.read_hdf('FoodPrice.h5', 'table')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 # Đọc dữ liệu từ file hdf5
# ----> 2 df=pd.read_hdf('FoodPrice.h5', 'table')
#       3 df.head()
#
# File ~\anaconda3\lib\site-packages\pandas\io\pytables.py:427, in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     424     exists = False
#     426 if not exists:
# --> 427     raise FileNotFoundError(f"File {path_or_buf} does not exist")
#     429 store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#     430 # can't auto open/close if we are using an iterator
#     431 # so delegate to the iterator
#
# FileNotFoundError: File FoodPrice.h5 does not exist

# %%
# Đọc dữ liệu từ file html
url = 'https://en.wikipedia.org/wiki/List_of_sovereign_states_and_dependent_territories_in_North_America'
df = pd.read_html(url)
df[0].head()
# Out:
#    Flag  Map English short, formal names, and ISO[1][2][3][4]  \
# 0   NaN  NaN                      Antigua and Barbuda[n 1]ATG
# 1   NaN  NaN  Bahamas, The[n 1]Commonwealth of The BahamasBHS
# 2   NaN  NaN                                 Barbados[n 1]BRB
# 3   NaN  NaN                              Belize[n 1][n 2]BLZ
# 4   NaN  NaN                                   Canada[n 3]CAN
#
#             Domestic short and formal name(s)[1][2] Capital[3][5][6]  \
# 0                      English: Antigua and Barbuda       St. John's
# 1  English: The Bahamas—Commonwealth of The Bahamas           Nassau
# 2                                 English: Barbados       Bridgetown
# 3                                   English: Belize         Belmopan
# 4                     English: CanadaFrench: Canada           Ottawa
#
#    Population 2021[7][8]                          Area[9]  \
# 0                  93219            442.6 km2 (171 sq mi)
# ...
