# %%
import pandas as pd
import numpy as np
data = pd.read_csv('D:\DA - TÚ\Data\database\GDPlist.csv',
                  header=0, encoding = 'ISO-8859-1')
data
# Out:
#           Country      Continent  GDP (millions of US$)
# 0     Afghanistan           Asia                  18181
# 1         Albania         Europe                  12847
# 2         Algeria         Africa                 190709
# 3          Angola         Africa                 100948
# 4       Argentina  South America                 447644
# ..            ...            ...                    ...
# 120    Uzbekistan           Asia                  45353
# 121     Venezuela  South America                 315841
# 122       Vietnam           Asia                 122722
# 123         Yemen         Africa                  33675
# 124        Zambia         Africa                  19206
#
# [125 rows x 3 columns]

# %%
# Đổi tên cột
data.columns = ['Nuoc', 'Chauluc', 'GDP (trieu $)']
data
# Out:
#              Nuoc        Chauluc  GDP (trieu $)
# 0     Afghanistan           Asia          18181
# 1         Albania         Europe          12847
# 2         Algeria         Africa         190709
# 3          Angola         Africa         100948
# 4       Argentina  South America         447644
# ..            ...            ...            ...
# 120    Uzbekistan           Asia          45353
# 121     Venezuela  South America         315841
# 122       Vietnam           Asia         122722
# 123         Yemen         Africa          33675
# 124        Zambia         Africa          19206
#
# [125 rows x 3 columns]

# %%
# chèn cột "Thanh pho" với giá trị là giá trị của cột "nước"
data.insert(1,'Thanhpho',data.loc[:,'Nuoc'])
data
# Out:
#              Nuoc      Thanhpho        Chauluc  GDP (trieu $)
# 0     Afghanistan   Afghanistan           Asia          18181
# 1         Albania       Albania         Europe          12847
# 2         Algeria       Algeria         Africa         190709
# 3          Angola        Angola         Africa         100948
# 4       Argentina     Argentina  South America         447644
# ..            ...           ...            ...            ...
# 120    Uzbekistan    Uzbekistan           Asia          45353
# 121     Venezuela     Venezuela  South America         315841
# 122       Vietnam       Vietnam           Asia         122722
# 123         Yemen         Yemen         Africa          33675
# 124        Zambia        Zambia         Africa          19206
#
# [125 rows x 4 columns]

# %%
# đổi 'Vietnam' thành 'Hanoi' trong cột 'Thanhpho'
data['Thanhpho'] = data['Thanhpho'].str.replace('Vietnam','Hanoi')
data
# Out:
#              Nuoc      Thanhpho        Chauluc  GDP (trieu $)
# 0     Afghanistan   Afghanistan           Asia          18181
# 1         Albania       Albania         Europe          12847
# 2         Algeria       Algeria         Africa         190709
# 3          Angola        Angola         Africa         100948
# 4       Argentina     Argentina  South America         447644
# ..            ...           ...            ...            ...
# 120    Uzbekistan    Uzbekistan           Asia          45353
# 121     Venezuela     Venezuela  South America         315841
# 122       Vietnam         Hanoi           Asia         122722
# 123         Yemen         Yemen         Africa          33675
# 124        Zambia        Zambia         Africa          19206
#
# [125 rows x 4 columns]

# %%
data2 = data.drop(data[data.Chauluc == 'Asia'].index)
display(data2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 data2 = data.drop(data[data.Chauluc == 'Asia'].index)
#       2 display(data2)
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
data3 = data.drop(data[data.['GDP (trieu $)'] < 300000].index)
display(data3)
# Out:
#   Input In [13]
#     data3 = data.drop(data.loc[data.['GDP (trieu $)'] < 300000].index, axis=0,inplace=True)
#                                     ^
# SyntaxError: invalid syntax
