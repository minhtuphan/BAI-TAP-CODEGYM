# %%
import pandas as pd
import numpy as np
df = pd.read_csv("580d8009-3d8d-410a-b7ca-9e29851407b6_Data.csv")
df
# Out:
#                                  Series Name     Series Code  \
# 0                          Population, total     SP.POP.TOTL
# 1                          Population, total     SP.POP.TOTL
# 2                          Population, total     SP.POP.TOTL
# 3                          Population, total     SP.POP.TOTL
# 4                          Population, total     SP.POP.TOTL
# ...                                      ...             ...
# 11062  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
# 11063  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
# 11064  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
# 11065  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
# 11066  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
#
#                 Country Name Country Code     2012 [YR2012]     2013 [YR2013]  \
# 0                Afghanistan          AFG          30466479          31541209
# ...

# %%
# lọc .. --> np.nan
df
